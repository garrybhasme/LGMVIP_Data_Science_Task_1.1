# %% [markdown]
# # Name :- Gaurav R. Bhasme
# ## Project Name :- Iris Flower analysis (LGM task-1.1)
# #### Hey in this project I did the analysis of Iris flower dataset using python. How the lengths and widths of each species varies is analysed and  visualised in this project. By using the ML algorithms the predicction of length and width is also shown....

# %% [markdown]
# ##  Loading the libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing the "Iris Flower" dataset

# %%
pushpa=pd.read_csv('iris.csv')

# %% [markdown]
# ## Some basic operations on Data

# %%
pushpa.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
pushpa.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
pushpa.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
pushpa['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
pushpa.shape
# Out:
# (150, 6)

# %% [markdown]
# ## Max and min values in height and width

# %%
pushpa["SepalLengthCm"].max()
# Out:
# 7.9

# %%
pushpa["SepalWidthCm"].max()
# Out:
# 4.4

# %%
pushpa["PetalLengthCm"].max()
# Out:
# 6.9

# %%
pushpa["PetalWidthCm"].max()
# Out:
# 2.5

# %%
pushpa["SepalLengthCm"].min()
# Out:
# 4.3

# %%
pushpa["SepalWidthCm"].min()
# Out:
# 2.0

# %%
pushpa["PetalLengthCm"].min()
# Out:
# 1.0

# %%
pushpa["PetalWidthCm"].min()
# Out:
# 0.1

# %% [markdown]
# ## Data Cleaning

# %%
pushpa.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
pushpa.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ## Data visualising - frequency of height

# %%
plt.hist(pushpa['SepalLengthCm'])
plt.title('frequency of height of SepalLength')
plt.xlabel('Height')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(pushpa['SepalWidthCm'],color='g')
plt.title('frequency of height of SepalWidth')
plt.xlabel('Height')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(pushpa['PetalLengthCm'],color='orange')
plt.title('frequency of height of PetalLength')
plt.xlabel('Height')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(pushpa['PetalWidthCm'],color='red')
plt.title('frequency of height of Petalwidth')
plt.xlabel('Height')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Visualizing the realation between the all parameters

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',data=pushpa,hue='Species')
plt.show()

# %%
sns.scatterplot(x='PetalLengthCm',y='PetalWidthCm',data=pushpa,hue='Species')
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalWidthCm',data=pushpa,hue='Species')
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=pushpa,hue='Species')
plt.show()

# %%
sns.scatterplot(x='PetalLengthCm',y='SepalWidthCm',data=pushpa,hue='Species')
plt.show()

# %%
sns.boxplot(x='Species',y='SepalLengthCm',data=pushpa)
plt.show()

# %%
sns.boxplot(x='Species',y='SepalWidthCm',data=pushpa)
plt.show()

# %%
sns.boxplot(x='Species',y='PetalLengthCm',data=pushpa)
plt.show()

# %%
sns.boxplot(x='Species',y='PetalWidthCm',data=pushpa)
plt.show()

# %%
sns.jointplot(x='SepalLengthCm',y='PetalLengthCm',data=pushpa,hue='Species')
plt.show()

# %% [markdown]
# ## Species wise analysis

# %%
sns.pairplot(pushpa,hue='Species')
plt.show()

# %%
pushpa.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
corr=pushpa.corr()
sns.heatmap(corr,cmap='coolwarm',annot=True)
plt.show()

# %% [markdown]
# ## Checking the Mean_Square_Error by using ML

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
x=pushpa[['SepalLengthCm']]
y=pushpa[['PetalLengthCm']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
mean_squared_error(x_test,y_pred)
# Out:
# 5.190984539035056

# %%
y=pushpa[['SepalLengthCm']]
x=pushpa[['SepalWidthCm','PetalLengthCm','PetalWidthCm']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr2=LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.13395104854404893

# %% [markdown]
# # Thank You
